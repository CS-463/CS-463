# %% [markdown]
# # Lab 1: Exploring Data with pandas
#
# **CS 463 · Due Monday 8:30 AM in Canvas**
#
# Based on Exercises 8 and 9 in §2.4 of James, Witten, Hastie, Tibshirani, and Taylor,
# *An Introduction to Statistical Learning with Applications in Python* (Springer, 2023),
# adapted to the versions of the data in the `ISLP` package.
#
# - Complete **Part 1** and **Part 2**. **Part 3** is an optional stretch.
# - Replace every `YOUR CODE HERE` and `YOUR ANSWER HERE`. Written answers: 1–3 sentences.
# - Before submitting, run **Restart & Run All** and make sure every cell runs.
#
# `ch_2_demo.ipynb` demonstrates every tool you need.

# %%
import numpy as np
import pandas as pd
from matplotlib.pyplot import subplots
from ISLP import load_data

# %% [markdown]
# ## Part 1: College (Exercise 8)
#
# Data on 777 US colleges and universities. Variable definitions are on p. 65 of the book.

# %% [markdown]
# **8(a).** Load the data with `load_data('College')`, name it `College`, and show its shape.

# %%
### YOUR CODE HERE

# %% [markdown]
# **8(b).** *(Adapted.)* In the book's version of this file, the first column holds the
# college names. The `ISLP` version has no names, so rows are just numbered. Look at the
# first few rows and at `College.dtypes`. Which column is not numeric?

# %%
### YOUR CODE HERE

# %% [markdown]
# **Answer:**
#
# _YOUR ANSWER HERE_

# %% [markdown]
# **8(c).** Use `describe()` to produce a numerical summary of the variables.

# %%
### YOUR CODE HERE

# %% [markdown]
# **8(d).** Make a scatterplot matrix of `Top10perc`, `Apps`, and `Enroll`.

# %%
### YOUR CODE HERE

# %% [markdown]
# **8(e).** Make side-by-side boxplots of `Outstate` versus `Private`. What do you see?

# %%
### YOUR CODE HERE

# %% [markdown]
# **Answer:**
#
# _YOUR ANSWER HERE_

# %% [markdown]
# **8(f).** The book creates a variable `Elite`, marking colleges where more than 50% of new
# students were in the top 10% of their high school class, with the code below. Run it.

# %%
College['Elite'] = pd.cut(College['Top10perc'],
                          [0, 0.5, 1],
                          labels=['No', 'Yes'])
College['Elite'].value_counts()

# %% [markdown]
# **Why didn't this work? Now fix it.** Hint: compare the bin edges to the values in
# `College['Top10perc']`.

# %% [markdown]
# **Answer:**
#
# _YOUR ANSWER HERE_

# %%
### YOUR CODE HERE

# %% [markdown]
# Now make side-by-side boxplots of `Outstate` versus `Elite`.

# %%
### YOUR CODE HERE

# %% [markdown]
# ## Part 2: Auto (Exercise 9)
#
# The `ISLP` version of `Auto` has already dropped the rows with missing values
# (392 rows, versus 397 in the demo), and it uses the car names as the index.

# %%
Auto = load_data('Auto')
Auto.shape, Auto.isna().sum().sum()

# %% [markdown]
# **9(a).** Which predictors are quantitative, and which are qualitative? Watch for
# columns that store categories as numbers.

# %% [markdown]
# **Answer:**
#
# _YOUR ANSWER HERE_

# %% [markdown]
# **9(b).** What is the range of each quantitative predictor? Use `min()` and `max()`.
# For (b)–(d), treat every column except `origin` as quantitative.

# %%
### YOUR CODE HERE

# %% [markdown]
# **9(c).** What is the mean and standard deviation of each quantitative predictor?

# %%
### YOUR CODE HERE

# %% [markdown]
# **9(d).** Remove the 10th through 85th rows, then find the range, mean, and standard
# deviation of each quantitative predictor in what remains. **Check: 316 rows should
# remain.** If you get fewer, look at `Auto.index.duplicated().sum()`.

# %%
### YOUR CODE HERE

# %% [markdown]
# **9(e).** Using the full data set, make plots that show relationships among the
# predictors. Comment on two or three things you notice.

# %%
### YOUR CODE HERE

# %% [markdown]
# **Answer:**
#
# _YOUR ANSWER HERE_

# %% [markdown]
# **9(f).** Suppose we want to predict `mpg` from the other variables. Do your plots suggest
# that any of them would be useful? Justify your answer.

# %% [markdown]
# **Answer:**
#
# _YOUR ANSWER HERE_

# %% [markdown]
# ## Part 3: Stretch (optional)
#
# **8(g).** Use `subplots(2, 2)` to plot histograms of four quantitative `College`
# variables, trying different numbers of bins.

# %%
### YOUR CODE HERE

# %% [markdown]
# **8(h).** Keep exploring the `College` data, and summarize what you find.

# %%
### YOUR CODE HERE

# %% [markdown]
# **Answer:**
#
# _YOUR ANSWER HERE_
